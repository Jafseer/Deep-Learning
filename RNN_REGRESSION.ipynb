# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('weather.csv')
seq = data.iloc[:,:].values
print(seq)
# Out:
# [[ 8.  24.3  0.   3.4  6.3]
#  [14.  26.9  3.6  4.4  9.7]
#  [13.7 23.4  3.6  5.8  3.3]
#  ...
#  [12.5 19.9  0.   8.4  5.3]
#  [12.5 26.9  0.   5.   7.1]
#  [12.3 30.2  0.   6.  12.6]]

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 0      8.0     24.3       0.0          3.4       6.3
# 1     14.0     26.9       3.6          4.4       9.7
# 2     13.7     23.4       3.6          5.8       3.3
# 3     13.3     15.5      39.8          7.2       9.1
# 4      7.6     16.1       2.8          5.6      10.6

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back)]
		dataX.append(a)
		dataY.append(dataset[i + look_back])
	return np.array(dataX), np.array(dataY)

# %%
look_back = 2

scaler = MinMaxScaler(feature_range=(-1, 1))
seq_scaled = scaler.fit_transform(seq)

seq_train = seq_scaled[:300,:]
seq_test = seq_scaled[300:,:]
X_train,Y_train= create_dataset(seq_train,look_back)
X_test,Y_test= create_dataset(seq_test,look_back)
print(X_train)
print(Y_train)
# Out:
# [[[ 0.01526718  0.18439716 -1.         -0.52941176 -0.07352941]
#   [ 0.47328244  0.36879433 -0.81909548 -0.38235294  0.42647059]]
#
#  [[ 0.47328244  0.36879433 -0.81909548 -0.38235294  0.42647059]
#   [ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]]
#
#  [[ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]
#   [ 0.41984733 -0.43971631  1.          0.02941176  0.33823529]]
#
#  ...
#
#  [[-0.41221374 -0.53900709 -1.         -0.58823529 -0.73529412]
#   [-0.64122137 -0.67375887 -1.         -0.64705882  0.02941176]]
#
#  [[-0.64122137 -0.67375887 -1.         -0.64705882  0.02941176]
#   [-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]]
#
#  [[-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]
#   [-0.8778626  -0.5177305  -1.         -0.64705882  0.52941176]]]
# [[ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]
#  [ 0.41984733 -0.43971631  1.          0.02941176  0.33823529]
#  [-0.01526718 -0.39716312 -0.85929648 -0.20588235  0.55882353]
#  ...
#  [-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]
#  [-0.8778626  -0.5177305  -1.         -0.64705882  0.52941176]
#  [-0.66412214 -0.53191489 -1.         -0.64705882  0.14705882]]

# %%
from keras.optimizers import RMSprop
model = keras.Sequential()
model.add(layers.SimpleRNN(50, input_shape=(look_back,5)))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(5))
opt = RMSprop(learning_rate=0.0001, momentum=0.9, decay=0.01)
model.compile(loss='mean_squared_error', optimizer=opt)
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4724
# Epoch 2/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3180
# Epoch 3/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2145
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1704
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1454
# Epoch 6/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1392
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1352
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1284
# Epoch 9/100
# 5/5 [==============================] - ETA: 0s - loss: 0.091 - 0s 3ms/step - loss: 0.1177
# Epoch 10/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1207
# Epoch 11/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1153
# Epoch 12/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1112
# Epoch 13/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1102
# Epoch 14/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1081
# Epoch 15/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1067
# Epoch 16/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1046
# Epoch 17/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1097
# Epoch 18/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1061
# Epoch 19/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1025
# Epoch 20/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1006
# Epoch 21/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1003
# Epoch 22/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0987
# Epoch 23/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0954
# Epoch 24/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0974
# Epoch 25/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0984
# Epoch 26/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0976
# Epoch 27/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0925
# Epoch 28/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0946
# Epoch 29/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0921
# Epoch 30/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0928
# Epoch 31/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0920
# Epoch 32/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0909
# Epoch 33/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0927
# Epoch 34/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0914
# Epoch 35/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0893
# Epoch 36/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0927
# Epoch 37/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0921
# Epoch 38/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0918
# Epoch 39/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 40/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0926
# Epoch 41/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0883
# Epoch 42/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0902
# Epoch 43/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 44/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0902
# Epoch 45/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 46/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 47/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0875
# Epoch 48/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0899
# Epoch 49/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0886
# Epoch 50/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0873
# Epoch 51/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0880
# Epoch 52/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0876
# Epoch 53/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0893
# Epoch 54/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0894
# Epoch 55/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 56/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 57/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0864
# Epoch 58/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0865
# Epoch 59/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0864
# Epoch 60/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0861
# Epoch 61/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0871
# Epoch 62/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0881
# Epoch 63/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0869
# Epoch 64/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0875
# Epoch 65/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 66/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 67/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 68/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0877
# Epoch 69/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0848
# Epoch 70/100
# 5/5 [==============================] - ETA: 0s - loss: 0.081 - 0s 2ms/step - loss: 0.0855
# Epoch 71/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0839
# Epoch 72/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 73/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0874
# Epoch 74/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0877
# Epoch 75/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 76/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0827
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0877
# Epoch 78/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0859
# Epoch 79/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0846
# Epoch 80/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0837
# Epoch 81/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0852
# Epoch 82/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0876
# Epoch 83/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 84/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0832
# Epoch 85/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0864
# Epoch 86/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0825
# Epoch 87/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0838
# Epoch 88/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 90/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0840
# Epoch 91/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0830
# Epoch 92/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0828
# Epoch 93/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0842
# Epoch 94/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0841
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 96/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0847
# Epoch 97/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0852
# Epoch 98/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0844
# Epoch 99/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0817
# Epoch 100/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0837

# %%
seq_train_pred_scaled = model.predict(X_train)
seq_train_pred = scaler.inverse_transform(seq_train_pred_scaled)
X_train_org = scaler.inverse_transform(seq_train)
print(seq_train_pred)
for i in range(5):
  plt.plot(X_train_org[:,i],label='True')
  plt.plot(seq_train_pred[:,i],label='Predicted')
  plt.legend()
  plt.show()
# Out:
# [[11.992837   24.7216      1.4323213   6.1561875   8.144566  ]
#  [13.118745   23.472189    5.871401    4.5786567   6.563607  ]
#  [ 5.4181037  19.762388    9.769611    5.117109    8.892884  ]
#  ...
#  [ 0.4961612  13.510286    0.45926693  1.5164909   6.924987  ]
#  [ 0.04113239 13.437389    0.05451583  2.7296214   8.404344  ]
#  [-0.52942514 15.525212   -1.8237783   2.8187943   8.125245  ]]

# %%
seq_test_pred_scaled = model.predict(X_test)
seq_test_pred = scaler.inverse_transform(seq_test_pred_scaled)
X_test_org = scaler.inverse_transform(seq_test)
#print(seq_pred)
for i in range(5):
  plt.plot(X_test_org[:,i],label='True')
  plt.plot(seq_test_pred[:,i],label='Predicted')
  plt.legend()
  plt.show()

# %%
seq_test_pred_scaled = model.predict(X_train)
seq_test_pred = scaler.inverse_transform(seq_test_pred_scaled)
X_test_org = scaler.inverse_transform(seq_train)
#print(seq_pred)
for i in range(5):
  plt.plot(X_test_org[:,i],label='True')
  plt.plot(seq_test_pred[:,i],label='Predicted')
  plt.legend()
  plt.show()
